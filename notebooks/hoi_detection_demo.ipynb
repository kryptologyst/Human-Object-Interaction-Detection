# %% [markdown]
# # Human-Object Interaction Detection
#
# This notebook demonstrates how to use the HOI detection package to detect and visualize human-object interactions in images.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd().parent / "src"))

import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2
from hoi_detection import HOIDetector
from hoi_detection.utils import visualize_hoi, setup_device, set_seed
